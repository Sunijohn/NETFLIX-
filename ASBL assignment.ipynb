# %%
from matplotlib import pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # getting the dataset

# %%
df = pd.read_excel("assignment.xlsx")
df.head()
# Out:
#       Type                  Title         Director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    Release_year                                             Genres
# 0          2020                                      Documentaries
# 1          2021    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df.tail()
# Out:
#          Type        Title         Director  \
# 8802    Movie       Zodiac    David Fincher
# 8803  TV Show  Zombie Dumb              NaN
# 8804    Movie   Zombieland  Ruben Fleischer
# 8805    Movie         Zoom     Peter Hewitt
# 8806    Movie       Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#       Release_year                                          Genres
# 8802          2007                  Cult Movies, Dramas, Thrillers
# 8803          2018          Kids' TV, Korean TV Shows, TV Comedies
# 8804          2009                         Comedies, Horror Movies
# ...

# %%
df.shape
# Out:
# (8807, 7)

# %%
df.size
# Out:
# 61649

# %%
df.columns
# Out:
# Index(['Type', 'Title', 'Director', 'Cast', 'Country', 'Release_year',
#        'Genres'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type            object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_year     int64
# Genres          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type          8807 non-null   object
#  1   Title         8807 non-null   object
#  2   Director      6173 non-null   object
#  3   Cast          7982 non-null   object
#  4   Country       7976 non-null   object
#  5   Release_year  8807 non-null   int64
#  6   Genres        8807 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 481.8+ KB

# %% [markdown]
# # to find duplicate records

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Type, Title, Director, Cast, Country, Release_year, Genres]
# Index: []

# %% [markdown]
# # find null values

# %%
df.isnull()
# Out:
#        Type  Title  Director   Cast  Country  Release_year  Genres
# 0     False  False     False   True    False         False   False
# 1     False  False      True  False    False         False   False
# 2     False  False     False  False     True         False   False
# 3     False  False      True   True     True         False   False
# 4     False  False      True  False    False         False   False
# ...     ...    ...       ...    ...      ...           ...     ...
# 8802  False  False     False  False    False         False   False
# 8803  False  False      True   True     True         False   False
# 8804  False  False     False  False    False         False   False
# 8805  False  False     False  False    False         False   False
# 8806  False  False     False  False    False         False   False
#
# [8807 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Type               0
# Title              0
# Director        2634
# Cast             825
# Country          831
# Release_year       0
# Genres             0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # handling null values

# %%
df.fillna({'Director' : 'Unavailaible','Cast' : 'Unavailaible','Country' : 'Unavailaible'})
# Out:
#          Type                  Title         Director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water     Unavailaible
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans     Unavailaible
# 4     TV Show           Kota Factory     Unavailaible
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb     Unavailaible
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 0                                          Unavailaible  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...   Unavailaible
# ...

# %% [markdown]
# # Visualisation

# %% [markdown]
# 1) lets take a look at type of shows that has been watched on netflix

# %%
df.Type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: Type, dtype: int64

# %%
sns.countplot(x='Type' , data = df)
plot.title('Count vs type of shows')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7640\3525323709.py in <module>
#       1 sns.countplot(x='Type' , data = df)
# ----> 2 plot.title('Count vs type of shows')
#
# NameError: name 'plot' is not defined

# %% [markdown]
# 2) country analysis

# %%
df.Country.value_counts()

# %%
df.Country.value_counts().head(10)

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='Country',order =  df.Country.value_counts().index[0:10],data = df )
plot.title('Country wise content on netflix')

# %% [markdown]
# 3) Chechking type of content based on country

# %%
movie_countries = df[df['Type'] == 'Movie']
tv_show_countries = df[df['Type'] == 'TV Show']

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='Country' ,order = df['Country'].value_counts().index[0:10],data = movie_countries)
plt.title('Top 10 countries producing movies in netflix')


plt.figure(figsize=(12,6))
sns.countplot(y='Country' ,order = df['Country'].value_counts().index[0:10],data = tv_show_countries)
plt.title('Top 10 countries producing tv_shows in netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 countries producing tv_shows in netflix')

# %% [markdown]
# 4) find release year

# %%
df.Release_year.value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: Release_year, Length: 74, dtype: int64

# %%
df.Release_year.value_counts()[:20]
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# Name: Release_year, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x ='Release_year' ,order = df['Release_year'].value_counts().index[0:10],data = df)
plt.title('Content Release in years on Netflix vs count')
# Out:
# Text(0.5, 1.0, 'Content Release in years on Netflix vs count')

# %% [markdown]
# 5) Popular genre analysis

# %%
plt.figure(figsize=(12,8))
sns.countplot(y ='Genres' ,order = df['Genres'].value_counts().index[0:20],data = df)
plt.title('Top 20 genres on netflix')
# Out:
# Text(0.5, 1.0, 'Top 20 genres on netflix')

# %%
df[df.Type == 'Movie'].Director
# Out:
# 0                     Kirsten Johnson
# 6       Robert Cullen, José Luis Ucha
# 7                        Haile Gerima
# 9                      Theodore Melfi
# 12                Christian Schwochow
#                     ...
# 8801                  Majid Al Ansari
# 8802                    David Fincher
# 8804                  Ruben Fleischer
# 8805                     Peter Hewitt
# 8806                      Mozez Singh
# Name: Director, Length: 6131, dtype: object

# %% [markdown]
# # SUMMARY
#
# 1) NETFLIX has more movies than TV shows
#
# 2) Most number of movies are produced by United States followed by INDIA
#
# 3) 2018 is the year in which NETFLIX release most number of content as compared to other years
#
# 4) Dramas,International Movies are the most popular Genres on Netflix

# %% [markdown]
# # Recommendations
#
# 1) NETFLIX should also give equal focus to TV SHOWS as the number of TV SHOWS doesnt even account to 50% of the number of movies
#
# 2) The content from United States is dominated the NETFLIX and so NETFLIX should give chance to content from other countries as well as this will bring variation to the contents and also
#
# 3) NETFLIX should work on their content more so that people also consume content from different genre

# %%
df.groupby(['Director'])['Type'].max()
# Out:
# Director
# A. L. Vijay            Movie
# A. Raajdheep           Movie
# A. Salaam              Movie
# A.R. Murugadoss        Movie
# Aadish Keluskar        Movie
#                        ...
# Çagan Irmak            Movie
# Ísold Uggadóttir       Movie
# Óskar Thór Axelsson    Movie
# Ömer Faruk Sorak       Movie
# Şenol Sönmez           Movie
# Name: Type, Length: 4528, dtype: object

# %%
df["Director"].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: Director, Length: 4528, dtype: int64

# %%
df["Director"].value_counts().head(5)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: Director, dtype: int64

# %% [markdown]
# # dividing dataset based on Type = Movie

# %%
movies_df = df.loc[(df['Type']=="Movie")]

# %%
movies_df
# Out:
#        Type                             Title                       Director  \
# 0     Movie              Dick Johnson Is Dead                Kirsten Johnson
# 6     Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7     Movie                           Sankofa                   Haile Gerima
# 9     Movie                      The Starling                 Theodore Melfi
# 12    Movie                      Je Suis Karl            Christian Schwochow
# ...     ...                               ...                            ...
# 8801  Movie                           Zinzana                Majid Al Ansari
# 8802  Movie                            Zodiac                  David Fincher
# 8804  Movie                        Zombieland                Ruben Fleischer
# 8805  Movie                              Zoom                   Peter Hewitt
# 8806  Movie                            Zubaan                    Mozez Singh
#
# ...

# %%
movies_df["Director"].value_counts()
# Out:
# Rajiv Chilaka                 19
# Raúl Campos, Jan Suter        18
# Suhas Kadav                   16
# Marcus Raboy                  15
# Jay Karas                     14
#                               ..
# Dennis Rovira van Boekholt     1
# Naoto Amazutsumi               1
# Jenny Gage                     1
# Kaila York                     1
# Mozez Singh                    1
# Name: Director, Length: 4354, dtype: int64

# %% [markdown]
# # Top 5 directors who produce most of the movies only

# %%
movies_df["Director"].value_counts().head(5)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              15
# Jay Karas                 14
# Name: Director, dtype: int64

# %%
movies_df["Director"].value_counts().nlargest(20)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Kunle Afolayan             8
# Johnnie To                 8
# Yılmaz Erdoğan             8
# Hakan Algül                8
# Fernando Ayllón            8
# Shannon Hartman            8
# Troy Miller                8
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %%
df.groupby(['Genres']).size().to_frame('Count').reset_index()
# Out:
#                                                 Genres  Count
# 0                                   Action & Adventure    128
# 1                   Action & Adventure, Anime Features      1
# 2    Action & Adventure, Anime Features, Children &...      4
# 3    Action & Adventure, Anime Features, Classic Mo...      2
# 4    Action & Adventure, Anime Features, Horror Movies      1
# ..                                                 ...    ...
# 509             TV Horror, TV Mysteries, Teen TV Shows      1
# 510                           TV Horror, Teen TV Shows      2
# 511                  TV Sci-Fi & Fantasy, TV Thrillers      1
# 512                                           TV Shows     16
# 513                                          Thrillers     65
#
# [514 rows x 2 columns]

# %% [markdown]
# # top 5 genres which are most liked by people

# %%
df.groupby(['Genres']).size().nlargest(5)
# Out:
# Genres
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# dtype: int64

# %% [markdown]
# # top 5 actors having most content

# %%
df.groupby(['Cast']).size().nlargest(10)
# Out:
# Cast
# David Attenborough                                                                                                        19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                   14
# Samuel West                                                                                                               10
# Jeff Dunham                                                                                                                7
# Craig Sechler                                                                                                              6
# David Spade, London Hughes, Fortune Feimster                                                                               6
# Kevin Hart                                                                                                                 6
# ...

# %% [markdown]
# # directors who have the highest number of content

# %%
df.groupby(["Director"]).size().to_frame('Count').reset_index()
# Out:
#                  Director  Count
# 0             A. L. Vijay      2
# 1            A. Raajdheep      1
# 2               A. Salaam      1
# 3         A.R. Murugadoss      2
# 4         Aadish Keluskar      1
# ...                   ...    ...
# 4523          Çagan Irmak      1
# 4524     Ísold Uggadóttir      1
# 4525  Óskar Thór Axelsson      1
# 4526     Ömer Faruk Sorak      2
# 4527         Şenol Sönmez      2
#
# [4528 rows x 2 columns]

# %%
df.groupby(["Director"]).size().nlargest(10)
# Out:
# Director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          11
# dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(y ='Director' ,order = df['Director'].value_counts().index[0:10],data = df)
plt.title('Director vs count')
# Out:
# Text(0.5, 1.0, 'Director vs count')

# %% [markdown]
# # Netflix should collaborate with the top 2 directors

# %% [markdown]
# # Actors who have the highest number of content

# %%
plt.figure(figsize=(15,6))
sns.countplot(y ='Cast' ,order = df['Cast'].value_counts().index[0:10],data = df)
plt.title('actor vs count')
# Out:
# Text(0.5, 1.0, 'actor vs count')

# %% [markdown]
# # netflix should collaborate with top 2 actors
